# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('outputDataT1.csv',header=None)
df.head()
# Out:
#                       0                1  2     3      4     5
# 0  ../instances/i-1.txt   epsilon-greedy  0  0.02    100   2.0
# 1  ../instances/i-1.txt   epsilon-greedy  0  0.02    400  -6.0
# 2  ../instances/i-1.txt   epsilon-greedy  0  0.02   1600  -5.0
# 3  ../instances/i-1.txt   epsilon-greedy  0  0.02   6400  27.0
# 4  ../instances/i-1.txt   epsilon-greedy  0  0.02  25600  38.0

# %%
df.columns = ['instance','algo','seed','eps','horizon','REG']

# %%
#df_group = df.groupby(['instance','algo','horizon']).mean()

# %%
df_i1 = df[:1200]
df_i2 = df[1200:2400]
df_i3 = df[2400:]

# %%
i_1_plot = df_i1.groupby(['algo','horizon']).mean()

# %%
i_1_plot
# Out:
#                             seed   eps     REG
# algo               horizon
#  epsilon-greedy    100      24.5  0.02   11.34
#                    400      24.5  0.02   17.28
#                    1600     24.5  0.02   24.64
#                    6400     24.5  0.02   45.16
#                    25600    24.5  0.02  110.22
#                    102400   24.5  0.02  419.44
#  kl-ucb            100      24.5  0.02    2.72
#                    400      24.5  0.02    5.88
#                    1600     24.5  0.02    8.60
#                    6400     24.5  0.02   13.66
#                    25600    24.5  0.02    6.96
#                    102400   24.5  0.02    2.92
#  thompson-sampling 100      24.5  0.02    3.10
#                    400      24.5  0.02    4.98
#                    1600     24.5  0.02    9.28
#                    6400     24.5  0.02   15.98
#                    25600    24.5  0.02    5.14
#                    102400   24.5  0.02   -1.08
#  ucb               100      24.5  0.02    8.24
#                    400      24.5  0.02   15.90
#                    1600     24.5  0.02   26.46
#                    6400     24.5  0.02   37.16
#                    25600    24.5  0.02   43.02
#                    102400   24.5  0.02   56.90

# %%
horizon = np.log([100,400,1600,6400,25600,102400])

# %%
plt.figure(figsize=(12,8))
plt.plot(horizon,i_1_plot['REG'][0:6], label="epsilon-greedy")
plt.plot(horizon,i_1_plot['REG'][6:12],label="KL-UCB")
plt.plot(horizon,i_1_plot['REG'][12:18],label="Thompson-sampling")
plt.plot(horizon,i_1_plot['REG'][18:24],label="UCB")
plt.xlabel('log(horizon)')
plt.ylabel('Regret')
plt.title("Regret vs Horizon for Instance i-1.txt")
plt.legend()
plt.savefig("i1.png")

# %%
i_2_plot = df_i2.groupby(['algo','horizon']).mean()

# %%
#i_2_plot

# %%
plt.figure(figsize=(12,8))
plt.plot(horizon,i_2_plot['REG'][0:6], label="epsilon-greedy")
plt.plot(horizon,i_2_plot['REG'][6:12],label="KL-UCB")
plt.plot(horizon,i_2_plot['REG'][12:18],label="Thompson-sampling")
plt.plot(horizon,i_2_plot['REG'][18:24],label="UCB")
plt.xlabel('log(horizon)')
plt.ylabel('Regret')
plt.title("Regret vs Horizon for Instance i-2.txt")
plt.legend()
plt.savefig("i2.png")

# %%
i_3_plot = df_i3.groupby(['algo','horizon']).mean()

# %%
i_3_plot
# Out:
#                             seed   eps      REG
# algo               horizon
#  epsilon-greedy    100      24.5  0.02    19.04
#                    400      24.5  0.02    32.12
#                    1600     24.5  0.02    64.78
#                    6400     24.5  0.02   143.52
#                    25600    24.5  0.02   404.64
#                    102400   24.5  0.02  1182.92
#  kl-ucb            100      24.5  0.02    21.46
#                    400      24.5  0.02    52.02
#                    1600     24.5  0.02    83.48
#                    6400     24.5  0.02   120.88
#                    25600    24.5  0.02   158.60
#                    102400   24.5  0.02   199.98
#  thompson-sampling 100      24.5  0.02    22.82
#                    400      24.5  0.02    44.16
#                    1600     24.5  0.02    65.24
#                    6400     24.5  0.02    84.92
#                    25600    24.5  0.02   108.18
#                    102400   24.5  0.02   127.86
#  ucb               100      24.5  0.02    35.78
#                    400      24.5  0.02   118.40
#                    1600     24.5  0.02   332.24
#                    6400     24.5  0.02   743.92
#                    25600    24.5  0.02  1288.04
#                    102400   24.5  0.02  1813.20

# %%
plt.figure(figsize=(12,8))
plt.plot(horizon,i_3_plot['REG'][0:6], label="epsilon-greedy")
plt.plot(horizon,i_3_plot['REG'][6:12],label="KL-UCB")
plt.plot(horizon,i_3_plot['REG'][12:18],label="Thompson-sampling")
plt.plot(horizon,i_3_plot['REG'][18:24],label="UCB")
plt.xlabel('log(horizon)')
plt.ylabel('Regret')
plt.title("Regret vs Horizon for Instance i-3.txt")
plt.legend()
plt.savefig("i3.png")

# %%
eps_explore = pd.read_csv('T3_data.txt',delimiter=",",header=None)

# %%
eps_explore.columns = ['instance','algo','seed','eps','horizon','REG']
eps_explore
# Out:
#                   instance             algo  seed       eps  horizon      REG
# 0     ../instances/i-1.txt   epsilon-greedy     0  0.000001   102400    -19.0
# 1     ../instances/i-1.txt   epsilon-greedy     0  0.100001   102400   2204.0
# 2     ../instances/i-1.txt   epsilon-greedy     0  0.200001   102400   4563.0
# 3     ../instances/i-1.txt   epsilon-greedy     0  0.300001   102400   6513.0
# 4     ../instances/i-1.txt   epsilon-greedy     0  0.400001   102400   8384.0
# ...                    ...              ...   ...       ...      ...      ...
# 1495  ../instances/i-3.txt   epsilon-greedy    49  0.500001   102400  21406.0
# 1496  ../instances/i-3.txt   epsilon-greedy    49  0.600001   102400  25523.0
# 1497  ../instances/i-3.txt   epsilon-greedy    49  0.700001   102400  29748.0
# 1498  ../instances/i-3.txt   epsilon-greedy    49  0.800001   102400  33986.0
# 1499  ../instances/i-3.txt   epsilon-greedy    49  0.900001   102400  38507.0
#
# [1500 rows x 6 columns]

# %%
eps_explore.groupby(['instance','algo','eps']).mean()
# Out:
#                                                seed   horizon       REG
# instance             algo            eps
# ../instances/i-1.txt  epsilon-greedy 0.000001  24.5  102400.0  14374.66
#                                      0.100001  24.5  102400.0   2037.70
#                                      0.200001  24.5  102400.0   4077.26
#                                      0.300001  24.5  102400.0   6136.32
#                                      0.400001  24.5  102400.0   8182.02
#                                      0.500001  24.5  102400.0  10229.60
#                                      0.600001  24.5  102400.0  12308.22
#                                      0.700001  24.5  102400.0  14368.82
#                                      0.800001  24.5  102400.0  16400.66
#                                      0.900001  24.5  102400.0  18416.98
# ../instances/i-2.txt  epsilon-greedy 0.000001  24.5  102400.0   9753.24
#                                      0.100001  24.5  102400.0   2067.16
#                                      0.200001  24.5  102400.0   4069.54
#                                      0.300001  24.5  102400.0   6133.72
#                                      0.400001  24.5  102400.0   8193.70
#                                      0.500001  24.5  102400.0  10240.02
#                                      0.600001  24.5  102400.0  12296.66
#                                      0.700001  24.5  102400.0  14370.82
#                                      0.800001  24.5  102400.0  16404.30
#                                      0.900001  24.5  102400.0  18429.30
# ../instances/i-3.txt  epsilon-greedy 0.000001  24.5  102400.0   4533.54
#                                      0.100001  24.5  102400.0   4285.08
#                                      0.200001  24.5  102400.0   8530.24
#                                      0.300001  24.5  102400.0  12754.80
#                                      0.400001  24.5  102400.0  16939.36
#                                      0.500001  24.5  102400.0  21171.94
#                                      0.600001  24.5  102400.0  25409.38
#                                      0.700001  24.5  102400.0  29619.52
#                                      0.800001  24.5  102400.0  33889.66
#                                      0.900001  24.5  102400.0  38095.76

# %%
eps_new_explore = pd.read_csv('T3_data_new.txt',delimiter=",",header=None)

# %%
eps_new_explore.columns = ['instance','algo','seed','eps','horizon','REG']
eps_new_explore
# Out:
#                  instance             algo  seed       eps  horizon     REG
# 0    ../instances/i-1.txt   epsilon-greedy     0  0.100001   102400  2204.0
# 1    ../instances/i-1.txt   epsilon-greedy     0  0.200001   102400  4563.0
# 2    ../instances/i-1.txt   epsilon-greedy     1  0.100001   102400  2075.0
# 3    ../instances/i-1.txt   epsilon-greedy     1  0.200001   102400  4272.0
# 4    ../instances/i-1.txt   epsilon-greedy     2  0.100001   102400  1979.0
# ..                    ...              ...   ...       ...      ...     ...
# 295  ../instances/i-3.txt   epsilon-greedy    47  0.200001   102400  8653.0
# 296  ../instances/i-3.txt   epsilon-greedy    48  0.100001   102400  4160.0
# 297  ../instances/i-3.txt   epsilon-greedy    48  0.200001   102400  8406.0
# 298  ../instances/i-3.txt   epsilon-greedy    49  0.100001   102400  4315.0
# 299  ../instances/i-3.txt   epsilon-greedy    49  0.200001   102400  8660.0
#
# [300 rows x 6 columns]

# %%
eps_new_explore.groupby(['instance','algo','eps']).mean()
# Out:
#                                                seed   horizon      REG
# instance             algo            eps
# ../instances/i-1.txt  epsilon-greedy 0.100001  24.5  102400.0  2037.70
#                                      0.200001  24.5  102400.0  4077.26
# ../instances/i-2.txt  epsilon-greedy 0.100001  24.5  102400.0  2067.16
#                                      0.200001  24.5  102400.0  4069.54
# ../instances/i-3.txt  epsilon-greedy 0.100001  24.5  102400.0  4285.08
#                                      0.200001  24.5  102400.0  8530.24

# %%
eps1_new_explore = pd.read_csv('T3_data_new_eps1.txt',delimiter=",",header=None)

# %%
eps1_new_explore.columns = ['instance','algo','seed','eps','horizon','REG']
eps1_new_explore
# Out:
#                 instance             algo  seed     eps  horizon      REG
# 0   ../instances/i-1.txt   epsilon-greedy     0  0.0001   102400    248.0
# 1   ../instances/i-1.txt   epsilon-greedy     1  0.0001   102400   9101.0
# 2   ../instances/i-1.txt   epsilon-greedy     2  0.0001   102400    636.0
# 3   ../instances/i-1.txt   epsilon-greedy     3  0.0001   102400  17530.0
# 4   ../instances/i-1.txt   epsilon-greedy     4  0.0001   102400   4951.0
# ..                   ...              ...   ...     ...      ...      ...
# 95  ../instances/i-2.txt   epsilon-greedy    45  0.0010   102400    -36.0
# 96  ../instances/i-2.txt   epsilon-greedy    46  0.0010   102400   8521.0
# 97  ../instances/i-2.txt   epsilon-greedy    47  0.0010   102400    258.0
# 98  ../instances/i-2.txt   epsilon-greedy    48  0.0010   102400   3810.0
# 99  ../instances/i-2.txt   epsilon-greedy    49  0.0010   102400    -61.0
#
# [100 rows x 6 columns]

# %%
eps1_new_explore.groupby(['instance','algo','eps']).mean()
# Out:
#                                              seed   horizon      REG
# instance             algo            eps
# ../instances/i-1.txt  epsilon-greedy 0.0001  24.5  102400.0  2372.88
# ../instances/i-2.txt  epsilon-greedy 0.0010  24.5  102400.0  2226.36

# %%
import random

# %%
random.seed(0)
i=0
while i < 10:
    p=random.betavariate(i+1,10-i+1)
    if p > 0.8:
        break
    print(p)
    i+=1
    print(i)
# Out:
# 0.11649099356921502
# 1
# 0.10637932967608642
# 2
# 0.17477483077548966
# 3
# 0.2733330346842517
# 4
# 0.2734082360481111
# 5
# 0.709499742096569
# 6
# 0.4972238969666635
# 7
# 0.437946162581028
# 8
